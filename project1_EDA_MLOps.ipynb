# %% [markdown]
# <a href="https://colab.research.google.com/github/FGC97/project1_Henry/blob/main/project1_EDA_MLOps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_movies = pd.read_csv('/content/drive/MyDrive/Proyectos Henry/ML_Ops_Project/df_movies.csv', sep=",")
df_movies.info()

# %% [markdown]
# # ***Exploratory Data Analysis (EDA)***
#
# * An important step in the data analysis process. It involves investigating the relationships between variables, identifying outliers or anomalies, and discovering interesting patterns that can guide further analysis.
# * In EDA, we explore the data manually, without relying on automated tools, to gain a deeper understanding of the dataset. One useful technique in EDA is word clouds, which provide insights into the most frequent words in titles. These word clouds can potentially be helpful for our recommendation system.
# * By performing EDA, we can uncover valuable insights and make informed decisions for subsequent analysis.

# %%
# summary of the dataset for all numerical columns excluding NaN(Not-a-Number or missing ) values. Include='all' gives additional summary of the data
df_movies.describe(include='all')
# Out:
#                    id       title belongs_to_collection     genres  \
# count    45345.000000       45345                  4485      45345
# unique            NaN       42195                  1695       4065
# top               NaN  Cinderella       The Bowery Boys  ['Drama']
# freq              NaN          11                    29       4994
# mean    108035.740479         NaN                   NaN        NaN
# std     112180.079341         NaN                   NaN        NaN
# min          2.000000         NaN                   NaN        NaN
# 25%      26390.000000         NaN                   NaN        NaN
# 50%      59852.000000         NaN                   NaN        NaN
# 75%     156597.000000         NaN                   NaN        NaN
# max     469172.000000         NaN                   NaN        NaN
#
#               budget original_language            overview    popularity  \
# count   4.534500e+04             45334               44404  45345.000000
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45345 entries, 0 to 45344
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     45345 non-null  int64
#  1   title                  45345 non-null  object
#  2   belongs_to_collection  4485 non-null   object
#  3   genres                 45345 non-null  object
#  4   budget                 45345 non-null  float64
#  5   original_language      45334 non-null  object
#  6   overview               44404 non-null  object
#  7   popularity             45345 non-null  float64
#  8   production_companies   45345 non-null  object
#  9   production_countries   45345 non-null  object
#  10  release_date           45345 non-null  object
#  11  revenue                45345 non-null  float64
#  12  runtime                45099 non-null  float64
#  13  spoken_languages       45345 non-null  object
# ...

# %% [markdown]
# ## **Correlation Matrix**

# %%
plt.figure(figsize=(10, 6))  #Set the size of the shape to 10 units wide and 6 units tall
# Personalizar el mapa de calor
sns.heatmap(df_movies.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap Movies')
plt.show()
# Out:
# <ipython-input-139-505639af03c1>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_movies.corr(), annot=True, cmap='coolwarm', fmt='.2f')

# %% [markdown]
# ## **Analysis of the Correlation Matrix**:
#
# * ***Revenue and Vote Count***: The correlation coefficient between revenue and vote_count is 0.81, indicating a strong positive relationship. This means that there is a substantial tendency for movies with a higher vote count to generate higher revenue. It suggests that audience engagement, as measured by the number of votes, has a significant impact on a movie's financial success. Movies that receive more votes are more likely to attract a larger audience and generate higher revenue.
#
# * ***Revenue and Budget***: The correlation coefficient between revenue and budget is 0.77, indicating a strong positive relationship. This implies that movies with a larger budget tend to generate higher revenue. It aligns with the understanding that a larger investment in production, marketing, and other aspects can lead to greater financial returns. Higher-budget movies often have more resources available for creating visually appealing content, securing top talent, and implementing effective marketing campaigns, which can contribute to their revenue generation.
#
# * ***Return and Other Variables***: Interestingly, the return column shows almost no correlation with the other variables in the dataset. This indicates that the return on investment for movies is not significantly influenced by factors such as revenue, vote count, or budget. Other factors, such as marketing strategies, critical reception, or audience demographics, may have a more significant impact on a movie's financial success. It highlights the complexity of factors influencing the profitability of a movie beyond the variables considered in this dataset.

# %% [markdown]
# # **Pair Plot**
#
# Created to visualize the relationships and distributions between the multiple variables in our dataset. It allows us to examine the pairwise relationships between variables, especially in terms of correlation and patterns.

# %%
# Exclude the "id" column from the pair plot
columns_to_exclude = ["id"]
data = df_movies.drop(columns_to_exclude, axis=1)

# Set the style of the plot
sns.set(style="ticks")

# Create the pair plot
sns.pairplot(data=data, height=1.5)

# %% [markdown]
# ## **Analysis of the Pair Plot**:
#
# 1. The pair plot analysis reveals that recent movies, indicated by higher values in the ***release_year*** variable, exhibit higher values in several other variables such as ***budget, popularity, revenue, vote_average, and vote_count***. This finding suggests that there is a correlation between movie release year and these attributes.
# To gain a deeper understanding, it would be beneficial to conduct a more precise analysis of the movie count in relation to the year. This analysis could help identify the period with the highest concentration of movies, which may have implications for the recommendation model. By considering the correlation between ***movie count and other variables, such as revenue or popularity***, it is possible to assess the significance of different time periods and potentially exclude periods with an insignificant number of movies from the recommendation model.
# By excluding periods with low movie counts, the recommendation model can focus on time periods that are more representative and relevant to users. This refinement can improve the accuracy and effectiveness of the recommendations provided, ensuring that they align with the preferences and interests of users in the most relevant movie periods.
#
# 2. The pair plot analysis confirms the strong correlation between ***revenue, vote_count, and budget*** variables. These variables exhibit a clear positive relationship, indicating that movies with higher budgets tend to generate higher revenues and attract more votes. This correlation can be attributed to the fact that movies with higher production budgets often have larger marketing campaigns and attract a larger audience, resulting in increased revenue and vote counts.
#
#  Given the high correlation between ***revenue, vote_count, and budget***, it may be redundant to include all three variables in the recommendation model. (we are not using them)
#
# 3. The pair plot also reveals the presence of outliers in various variables. These outliers represent data points that deviate significantly from the majority of observations. However, for the purpose of our recommendation model, these outliers may not be relevant and can be safely ignored.

# %% [markdown]
# # **Histogram**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate a histogram with 14 bins for detailed view
plt.figure(figsize=(7, 4))
plt.hist(df_movies["release_year"], bins=14, density=False, alpha=0.8, color="blue")
plt.xlabel('Years')
plt.ylabel('Number of Movies')
plt.title('Distribution of Movies by Year')

# Iterate over the histogram to display the frequency (number of movies) on each bar
for freq, bin in zip(*plt.hist(df_movies["release_year"], bins=14, density=False)[0:2]):
    plt.text(bin, freq, str(int(freq)), ha='center', va='bottom')

# Generate a histogram with 3 bins for an overview
plt.figure(figsize=(7, 4))
plt.hist(df_movies["release_year"], bins=3, density=False, alpha=0.7, color="pink")

# Iterate over the histogram to display the frequency (number of movies) on each bar
for freq, bin in zip(*plt.hist(df_movies["release_year"], bins=3, density=False)[0:2]):
    plt.text(bin, freq, str(int(freq)), ha='center', va='bottom')

plt.xlabel('Years')
plt.ylabel('Number of Movies')
plt.title('Distribution of Movies by Year')

plt.show()

# %% [markdown]
# ## **Histogram Analysis**:
#
# The histogram provides insights into the distribution of movies over the years. It reveals that there is a lower number of movies in the earlier years, indicating a relatively smaller film industry during that period. However, as we move towards the 1960s and 1970s, the number of movies starts to increase, suggesting a growth and expansion of the film industry. This trend continues until the present day, with a larger concentration of movies in more recent years.
#
# The histogram also helps identify any significant peaks or clusters within the data. In this case, the separation at the 1960 mark highlights a notable increase in movie production, emphasizing a shift or notable period in the industry's history.
#
# Overall, the histogram visually represents the distribution of movies across different years, providing valuable insights into the trends and patterns of film production over time.

# %%
# Calculates the ratio of movies from 1957 onwards to the total number of movies in the dataset.
df_movies[df_movies["release_year"]>=1957].shape[0] / df_movies.shape[0] * 100
# Out:
# 89.03076414158122

# %% [markdown]
# Based on the analysis, it can be concluded that movies from the year 1957 onwards represent approximately 89.03% of the total dataset. This implies that the majority of the data is concentrated from this year onwards, and therefore, it may be possible to exclude the remaining data points to make the recommendation model more efficient. By working with 89.03% of the data starting from 1957, a significant portion of the dataset can still be captured while reducing computational complexity and improving the model's performance.

# %%
# create a new DataFrame that includes only the movies from the year 1957 onwards in order to improve the model's performance.
df_movies_ml = df_movies[df_movies["release_year"]>=1957]
df_movies_ml.shape
# Out:
# (40371, 22)

# %%
df_movies_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40371 entries, 0 to 45344
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     40371 non-null  int64
#  1   title                  40371 non-null  object
#  2   belongs_to_collection  4185 non-null   object
#  3   genres                 40371 non-null  object
#  4   budget                 40371 non-null  float64
#  5   original_language      40364 non-null  object
#  6   overview               39479 non-null  object
#  7   popularity             40371 non-null  float64
#  8   production_companies   40371 non-null  object
#  9   production_countries   40371 non-null  object
#  10  release_date           40371 non-null  object
#  11  revenue                40371 non-null  float64
#  12  runtime                40134 non-null  float64
#  13  spoken_languages       40371 non-null  object
# ...

# %% [markdown]
# ### ***Extra Analysis:***
#
# Verify for null values and movies that are cancelled in order to clean movies that are not available

# %%
# Check for missing values in the DataFrame
df_movies_ml.isna().sum().sort_values(ascending=False)
# Out:
# belongs_to_collection    36186
# tagline                  22359
# overview                   892
# runtime                    237
# status                      79
# original_language            7
# id                           0
# spoken_languages             0
# release_year                 0
# actors                       0
# director                     0
# vote_count                   0
# vote_average                 0
# revenue                      0
# title                        0
# release_date                 0
# production_countries         0
# production_companies         0
# popularity                   0
# budget                       0
# genres                       0
# return                       0
# dtype: int64

# %%
# Verify if there are any canceled movies
status_counts = df_movies_ml["status"].value_counts()
print(status_counts)
# Out:
# Released           39957
# Rumored              205
# Post Production       97
# In Production         19
# Planned               13
# Canceled               1
# Name: status, dtype: int64

# %%
# Print the rows of canceled movies
canceled_movies = df_movies_ml[df_movies_ml["status"] == "Canceled"]
print(canceled_movies)
# Out:
#           id   title belongs_to_collection genres  budget original_language  \
# 40331  64109  Paanch                   NaN     []     0.0                en
#
#                                                 overview  popularity  \
# 40331  The film is "loosely" based on the 1976-77 Jos...    0.189724
#
#       production_companies production_countries  ... runtime  \
# 40331                   []                   []  ...   130.0
#
#                               spoken_languages    status tagline vote_average  \
# 40331  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]  Canceled     NaN          6.3
#
#       vote_count            director  \
# 40331        3.0  ['Anurag Kashyap']
#
#                                                   actors release_year return
# 40331  ['Kay Kay Menon', 'Aditya Srivastava', 'Aditya...         2003    0.0
#
# [1 rows x 22 columns]

# %%
# Drop the row with the specified index
df_movies_ml = df_movies_ml.drop(index=40331)

# %% [markdown]
# # ***Useful variables for the model***

# %% [markdown]
# genres ,overview, title.
#
# id (to identify movies)
#
# vote_average (provide information)
#
# release_year (differentiate movies with the same title)

# %%
# Columns for recommendation:
df_movies_ml = df_movies_ml[["id", "genres", "overview", "title", "vote_average", "release_year"]]

# %% [markdown]
# ## **Word Clouds**

# %%
# !pip install wordcloud
from wordcloud import WordCloud

# %%
# Concatenate all the "title" records into a single string
title_text = ' '.join(df_movies_ml["title"].astype(str))

# Create a WordCloud object for the title
title_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(title_text)

# Concatenate all the "overview" records into a single string
overview_text = ' '.join(df_movies_ml['overview'].astype(str))

# Create a WordCloud object for the overview
overview_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(overview_text)

# Create a figure with two subplots
fig, axes = plt.subplots(2, 1, figsize=(8, 10))

# Plot the WordCloud of the title in the first subplot
axes[0].imshow(title_wordcloud, interpolation='bilinear')
axes[0].set_title('WordCloud of Movie Titles')
axes[0].axis('off')

# Plot the WordCloud of the overview in the second subplot
axes[1].imshow(overview_wordcloud, interpolation='bilinear')
axes[1].set_title('WordCloud of Movie Overviews')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # ***Exporting new dataframe for the ML Model***

# %%
# Create the path:
savefile_path = '/content/drive/MyDrive/Proyectos Henry/ML_Ops_Project/df_movies_ml.csv'

# DF export:
df_movies_ml.to_csv(savefile_path, index=False)

# %% [markdown]
# ## ***Machine Learning - Recommendation System:***
#
# Once all the data is consumable by the API and ready to be consumed by the Analytics and Machine Learning departments, and our EDA (Exploratory Data Analysis) allows us to understand the available data well, it's time to train our machine learning model to build a movie recommendation system. The EDA should include interesting visualizations to extract insights, such as a word cloud with the most frequent words in movie titles.
#
# This recommendation system aims to recommend movies to users based on similar movies. It involves finding the similarity in ratings between a given movie and the rest of the movies. The movies will be sorted based on the similarity score, and the system will return a Python list with 5 values, each representing the name of the movies with the highest scores in descending order.
#
# This recommendation system should be deployed as an additional function in the previous API and should be named:
#
# **Spanish**: <br>
#
# * ***def recomendacion(titulo)***: Se ingresa el nombre de una película y te recomienda las similares en una lista de 5 valores.
#
# **English**: <br>
#
# * ***def recomendacion(title)***: Enter the name of a movie and it recommends similar ones in a list of 5 values.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import ast

# %%
# df_movies = pd.read_csv('/content/drive/MyDrive/Proyectos Henry/ML_Ops_Project/df_movies.csv', sep=",")
df_movies = pd.read_csv('dataset/df_movies_ml.csv', sep=",")

# %%
def recomendacion(titulo: str):
    # Verify if the title is a string
    if not isinstance(titulo, str):
        return {"Error": f"'{titulo}' is not a string"}

    # Normalize the title
    titulo = titulo.strip().title()

    # Check if the title is present in the DataFrame
    matching_movies = df_movies_ml[df_movies_ml['title'].str.title() == titulo]
    if matching_movies.empty:
        return {"Error": f"The movie {titulo} was not found"}

    recommendations_dict = {}

    # Iterate over the matching movies
    for _, movie in matching_movies.iterrows():
        movie_title = movie['title']
        movie_anio = movie['release_year']
        movie_id = movie['id']
        movie_genre = ast.literal_eval(movie["genres"])

        # Check if the movie has at least one genre
        if len(movie_genre) == 0:
            return {"Error": f"No recommendations found for the movie {titulo}"}

        # Filter movies with the same genres as the current movie
        filtered_movies = df_movies_ml[df_movies_ml['genres'].apply(lambda x: len(ast.literal_eval(x)) == len(movie_genre) and ast.literal_eval(x) == movie_genre)]

        # Reset the index of the filtered DataFrame
        filtered_movies = filtered_movies.reset_index(drop=True)

        # Create a TF-IDF vectorizer for movie features (title and overview)
        tfidf = TfidfVectorizer(stop_words='english')

        # Combine the features (title and overview) into a single field
        filtered_movies['combined_features'] = filtered_movies['title'] + ' ' + filtered_movies['overview'].fillna('')

        # Calculate the TF-IDF matrix of the features
        tfidf_matrix = tfidf.fit_transform(filtered_movies['combined_features'])

        # Get the index corresponding to the movie ID of the input movie
        movie_index = filtered_movies[filtered_movies['id'] == movie_id].index[0]

        # Calculate the cosine similarity between the input movie and the filtered movies
        similarities = cosine_similarity(tfidf_matrix[movie_index], tfidf_matrix).flatten()

        # Get the indices of the top 5 most similar movies (excluding the input movie)
        top_indices = similarities.argsort()[-6:-1][::-1]

        recommendations = {}
        # Create a dictionary of recommendations for the current movie
        for idx in top_indices:
            rec_movie_title = filtered_movies.iloc[idx]['title']
            rec_movie_genres = filtered_movies.iloc[idx]['genres']
            rec_movie_vote_average = filtered_movies.iloc[idx]['vote_average']
            recommendations[rec_movie_title] = {'genres': rec_movie_genres, 'vote_average': rec_movie_vote_average}

        # Add the recommendations for the current movie to the final recommendations dictionary
        recommendations_dict[f"{movie_title}, year {movie_anio}"] = recommendations

    # Return the final dictionary containing recommendations for each movie matching the input title
    return recommendations_dict

# %%
recomendacion('THE Dark kNight')
#recomendacion('Treasure Island ')
# recomendacion("Hotel Transylvania")
